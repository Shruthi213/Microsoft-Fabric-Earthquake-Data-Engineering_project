# %%
# Worldwide Earthquake Events API - Bronze Layer Processing

# %%
from datetime import date, timedelta

start_date = date.today() - timedelta(7)
end_date = date.today() - timedelta(1)

url = f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_date}&endtime={end_date}"

print(url)
# Out:
# StatementMeta(, 9789a682-41d7-4ffe-ad57-5f7e08a30fc6, 4, Finished, Available, Finished)
# https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2024-09-21&endtime=2024-09-27

# %%
import requests
import json

# Construct the API URL with start and end dates provided by Data Factory, formatted for geojson output.
url = f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_date}&endtime={end_date}"

# Make the GET request to fetch data
response = requests.get(url)

# Check if the request was successful

if response.status_code == 200:
    # Get the JSON response
    data = response.json()
    data = data['features']
    
    # Specify the file name (and path if needed)
    file_path = f'/lakehouse/default/Files/{start_date}_earthquake_data.json'
    # /lakehouse/default/Files
    
    # Open the file in write mode ('w') and save the JSON data
    with open(file_path, 'w') as file:
        # The `json.dump` method serializes `data` as a JSON formatted stream to `file`
        # `indent=4` makes the file human-readable by adding whitespace
        json.dump(data, file, indent=4)
        
    print(f"Data successfully saved to {file_path}")
else:
    print("Failed to fetch data. Status code:", response.status_code)
# Out:
# StatementMeta(, 9789a682-41d7-4ffe-ad57-5f7e08a30fc6, 5, Finished, Available, Finished)
# Data successfully saved to /lakehouse/default/Files/2024-09-21_earthquake_data.json

# %%
df = spark.read.option("multiline", "true").json("Files/2024-09-21_earthquake_data.json")
# df now is a Spark DataFrame containing JSON data from "Files/2024-09-21_earthquake_data.json".
display(df)
# Out:
# StatementMeta(, db4d7d55-61bb-4dfa-9cb8-731036e3a30b, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 75ee8e2f-a1d2-4ad9-ba0b-91571cf7502e)
